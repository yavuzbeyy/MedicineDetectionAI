# %% [markdown]
# Sistem Özellikleri

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.6 LTS"

# %% [markdown]
# Depolama Alanı Güncelleme

# %%
# !apt-get update
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# ...

# %% [markdown]
# Adres Öğrenme

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# Dosyaları Zipden Çıkarma

# %%
# !unzip "/content/drive/MyDrive/Object_Detection/darknet.zip"
# Out:
# Archive:  /content/drive/MyDrive/Object_Detection/darknet.zip
#    creating: darknet/darknet/
#    creating: darknet/darknet/.circleci/
#   inflating: darknet/darknet/.circleci/config.yml
#   inflating: darknet/darknet/.gitignore
#    creating: darknet/darknet/3rdparty/
#    creating: darknet/darknet/3rdparty/pthreads/
#    creating: darknet/darknet/3rdparty/pthreads/bin/
#   inflating: darknet/darknet/3rdparty/pthreads/bin/pthreadGC2.dll
#   inflating: darknet/darknet/3rdparty/pthreads/bin/pthreadVC2.dll
#    creating: darknet/darknet/3rdparty/pthreads/include/
#   inflating: darknet/darknet/3rdparty/pthreads/include/pthread.h
#   inflating: darknet/darknet/3rdparty/pthreads/include/sched.h
#   inflating: darknet/darknet/3rdparty/pthreads/include/semaphore.h
#    creating: darknet/darknet/3rdparty/pthreads/lib/
#   inflating: darknet/darknet/3rdparty/pthreads/lib/libpthreadGC2.a
#   inflating: darknet/darknet/3rdparty/pthreads/lib/pthreadVC2.lib
# ...

# %% [markdown]
# Adres Ayarlama İşlemi

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# Dos2 Unix İndirme

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 22 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (457 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %% [markdown]
# Dosyaları Unix'e çevirme

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# dos2unix: Skipping binary file ./darknet/data/labels/109_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/75_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/117_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/113_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/46_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/104_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/73_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./darknet/data/labels/87_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# ...

# %% [markdown]
# İzin Alma

# %%
# !chmod +x /content/darknet

# %% [markdown]
# Çalıştırma

# %%
# %cd /content/darknet/darknet
# Out:
# /content/darknet/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# darknet Testi

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/dog.jpg
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# Dosya Silme ( drive'daki backupa bağlanmak için)

# %%
# !rm /content/darknet/darknet/backup -r

# %% [markdown]
# Drive Backup Bağlantısı

# %%
# !ln -s /content/drive/MyDrive/medicine_weights/backup /content/darknet/darknet

# %%
# %pwd
# Out:
# '/content/darknet/darknet'

# %% [markdown]
# Eğitime Başlama

# %%
# !./darknet detector train IlacData/ilac.data yolov4.cfg yolov4.conv.137 -map -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2313.641113, iou_loss = 0.000000, total_loss = 2313.641113
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.360349), count: 19, class_loss = 960.697510, iou_loss = 1.493958, total_loss = 962.191467
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.343427), count: 30, class_loss = 222.128998, iou_loss = 0.495956, total_loss = 222.624954
#  total_bbox = 36983, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.189732), count: 2, class_loss = 2301.243896, iou_loss = 0.385742, total_loss = 2301.629639
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.312988), count: 13, class_loss = 951.711914, iou_loss = 0.780640, total_loss = 952.492554
# ...

# %%
# !./darknet detector train IlacData/ilac.data yolov4.cfg /content/darknet/darknet/backup/yolov4_last.weights -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#  total_bbox = 677141, rewritten_bbox = 0.000000 %
#
#  2026: 0.465093, 0.449642 avg loss, 0.001300 rate, 7.335844 seconds, 129664 images, 808.661995 hours left
# Loaded: 4.909586 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.690465), count: 2, class_loss = 0.847662, iou_loss = 2.810593, total_loss = 3.658255
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.820688), count: 16, class_loss = 3.072921, iou_loss = 9.486947, total_loss = 12.559868
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.820208), count: 24, class_loss = 0.854853, iou_loss = 1.782092, total_loss = 2.636945
#  total_bbox = 677183, rewritten_bbox = 0.000000 %
# ...
